# %%
import pandas as pd
import pickle
import numpy as np
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
import pickle
import torchvision
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
import time
import sys
from utils import *
from networks import *
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import hamming_loss


n = 5000
seq_len = 20
h = 512
num_tags = 30
batch_size = 64

gpu = False

df = pd.read_csv('lyric_data.csv', index_col=0)#.iloc[0:200000]
#df = pd.read_csv('lyric_data_small.csv', index_col=0)


# Sometimes the API returns an error message rather than actual lyrics. This removes it
bad_song = df['lyrics'].value_counts().index[0]
df[df['lyrics'] == bad_song] = ''

# only take the ones that we have data for
df.fillna('', inplace=True)
df = df[df['lyrics'] != '']
df = df.drop_duplicates(['artist','song'])

# List of list of tags for each example
tags = [clean_tags(raw) for raw in list(df['tags'])]

# list of tuples of (tag, frequency) in desending order
tf = tag_freq(tags)

# Choose which tags to restrict model too
important_tags = [x[0] for x in tf[0:num_tags]]
important_tags = dict(zip(important_tags, range(len(important_tags))))

# maps each of the tags int 'tags' to an int index
indices = tag2index(tags, important_tags)

# Convert indices to binary vectors of tags
y = np.zeros((len(indices), num_tags))
for i, tags in enumerate(indices):
    for tag in tags:
        y[i, tag] = 1

# Build vocabulary and tokenizer
vect = CountVectorizer(max_features=n, stop_words='english')
vect.fit(df['lyrics'])
vocab = vect.vocabulary_
tok = vect.build_analyzer()


def load_glove(vocab):
    embedding_mat = [np.zeros(50)]
    new_vocab = {}
    new_vocab[''] = 0
    count = 0

    with open('/Users/Hadoop/Desktop/glove.6B.50d.txt') as f:

        for i, line in enumerate(f):

            s = line.split()

            if s[0] in vocab:
                embedding_mat.append(np.asarray(s[1:]))
                new_vocab[s[0]] = count
                count += 1

                if len(list(new_vocab.keys())) == len(list(vocab.keys())):
                    return new_vocab, np.array(embedding_mat)

    embedding_mat.append(np.random.randn(50))
    new_vocab['UNK'] = len(embedding_mat)
    
    return new_vocab, np.array(embedding_mat).astype(np.float32())

# Load glove vectors for word embedding
vocab, glove = load_glove(vocab)


# Convert text to sequence input
features = df['lyrics'].apply(lambda x: sent2seq(x, vocab, tok, seq_len))
features = np.array(list(features))

features = torch.from_numpy(features)
y = torch.from_numpy(y).float()
glove = torch.from_numpy(glove)
# Out:
# torch.Size([64, 100])

# %%
class LSTM_Model(nn.Module):

    def __init__(self,h,glove,num_out):
        super(LSTM_Model, self).__init__()

        self.h = h
        self.embed = nn.Embedding(glove.size()[0], glove.size()[1], padding_idx=0 )
        self.embed.weight = nn.Parameter(glove )

        #self.lstm = nn.LSTM(glove.size()[1], h, 1, batch_first=True)
        self.lstm = nn.GRU(glove.size()[1], h, 1, batch_first=True , dropout = .3, bidirectional = False)

        self.output_layer = nn.Linear(h, num_out,bias=False)

        self.params = list(self.embed.parameters()) + list(self.output_layer.parameters()) + list(self.lstm.parameters())
        #self.params =  list(self.output_layer.parameters()) + list(self.lstm.parameters())


    def forward(self,x):

        h0 = Variable(torch.zeros(1, x.size()[0], self.h))
        c0 = Variable(torch.zeros(1, x.size()[0], self.h))

        E = self.embed(x)
        
        z = self.lstm(E, h0)[0][:, -1, :]

        y_hat = F.sigmoid(self.output_layer(z))

        return y_hat

model = LSTM_Model(32,glove,num_tags)

print(model(data).size())
# Out:
# torch.Size([16, 30])

# %%
for p in output.parameters():
    print(p.grad)
# Out:
# Variable containing:
# -1.4444e-03 -1.6085e-03 -6.3256e-04  ...  -1.5683e-03 -1.2202e-03  1.1343e-04
# -1.0188e-03 -9.7500e-04 -5.2843e-04  ...  -3.4567e-04 -1.7049e-04  6.0790e-04
# -4.4641e-03 -1.2784e-03  9.6082e-04  ...  -4.7085e-05 -2.3517e-03 -4.8138e-04
#                 ...                   ⋱                   ...
# -7.7108e-03  4.2762e-03  3.7395e-03  ...   1.1472e-03 -1.2463e-04 -4.7277e-03
# -8.6352e-03  3.9344e-03  4.5240e-03  ...   1.7290e-03 -8.9400e-04 -4.9314e-03
# -8.2193e-03  3.7746e-03  4.3103e-03  ...   1.6525e-03 -8.5361e-04 -4.6865e-03
# [torch.FloatTensor of size 30x512]

# %%
bce = torch.nn.BCELoss()

data , target = Variable(features[0:16]) , Variable(y[0:16])
#y_hat = model(data)

embed= model.embed
lstm = model.lstm
output = model.output_layer
h = model.h

def forward(x):

    h0 = Variable(torch.zeros(1, x.size()[0], h))

    E = embed(x)

    z = lstm(E, h0)[0]
    #z.register_hook(lambda grad: print(grad))
    y_hat = F.sigmoid(output(z[:, -1, :]))

    return y_hat,z

y_hat, z= forward(data)

loss= bce(y_hat,target)
loss.backward()

# %%
vect2 = vect.copy(deep=True)
vect.inverse_transform(features[i].numpy())
# Out:
# [array(['000', '10', '100', '11', '12', '13', '15', '16', '17', '18', '1st',
#         '20', '21', '22', '24', '25', '2nd', '2x', '30', '3x'],
#        dtype='<U16')]

# %%
features[i].numpy()
# Out:
# array([ 102, 4978, 3764, 4978, 1644, 2929,  355,  194,  246,  482, 3105,
#           4,  725, 1000,  640, 2928,  474, 2487, 4978, 1567])

# %%
inv = dict([ (v,k) for k,v in vocab.items()])
inv[len(vocab.keys())+1] = 'UNK'
#inv[0] =

# %%
df[df['artist'] == 'Jimi Hendrix']
# Out:
#                                  file        artist  \
# 3248    A/E/T/TRAETTV12903CBBD09.json  Jimi Hendrix
# 3280    A/E/V/TRAEVIK12903CCC7E2.json  Jimi Hendrix
# 12290   A/S/C/TRASCWR12903CCC575.json  Jimi Hendrix
# 14588   A/V/M/TRAVMXD12903CBBD0B.json  Jimi Hendrix
# 23330   B/I/L/TRBILTL128F422619D.json  Jimi Hendrix
# 24917   B/K/V/TRBKVSV128F1455E1E.json  Jimi Hendrix
# 25219   B/L/H/TRBLHHI12903CC1839.json  Jimi Hendrix
# 26791   B/N/Q/TRBNQYY12903D021D4.json  Jimi Hendrix
# 31404   B/U/U/TRBUUHE12903CC182E.json  Jimi Hendrix
# 35215   C/A/L/TRCALEF12903D021D3.json  Jimi Hendrix
# 40056   C/H/P/TRCHPCS12903CC15D1.json  Jimi Hendrix
# 42942   C/L/X/TRCLXUH12903CC17DB.json  Jimi Hendrix
# 43288   C/M/L/TRCMLEW12903CBBCF8.json  Jimi Hendrix
# 51597   Well, I travel at a speed,\nOf a reborn man.\n...
# 57478   Hey Joe, where you goin' with that gun in your...
# 58069   Well, I stand up next to a mountain\nAnd I cho...
# 67485   "There must be some kind of way out of here"\n...
# 68428   I used to live in a room full of mirrors\nAll ...
# 73985   Well, I stand up next to a mountain\nAnd I cho...
# 74940   You know you're a cute little heartbreaker\nFo...
# 79966   Well, I see hands and attesting faces\nReachin...
# 88826   Ooh-WHEE!  I sure got the blues this morning, ...
# 89209   I feel the ocean swaying me ...\nWashing away ...
# 99135   Well. I'm up here in this womb\nI'm looking al...
# 109355  Mama\nMama hasn't...take one\nOh ooo yeah\nWho...
# 110256  When I first met you baby, honey you were almo...
# 125002  "Here he comes"\n"Here he comes take one"\n\nH...
# 128683  She's just a night bird flyin' through the nig...
# 140665  Well she's walking \nThrough the clouds\nTo th...
# 143597  I get stoned\nI can't go home\nI'm calling lon...
# 178810  Peoples, peoples, peoples\nYou know what it me...
# 181286  Izabella I'm dreamin about ya every night\nHey...
# 188009  Buddy miles is goin' to do something he wrote ...
# 198127  "We'd like to say, we'd like you to clap your ...
# 206547  Every day in the week I'm in a different city\...
# 210450  Burning desire sets my soul on fire\nBurning d...
# 211532  "Here he comes"\n"Here he comes take one"\n\nH...
# 221171  "Yeah well a like I said before we only ran up...
# 252408  You got my pride\nHanging outta my bed\nYou're...
# 260595  "Happy new year first of all. I hope we'll hav...
# 263751  Well I, I just came back today\nI just came ba...
# 270020  Peoples, peoples, peoples\nYou know what it me...
# 281715  There goes Ezy\nEzy Ryder\nRidin' down the hig...
# 305408  Hey, look out for my glass up there, man!\nTha...
# 313013  I'm just a lonesome ship passing through the n...
# 322175  Shoot down some of those airplanes your flyin'...
# 325882  I used to live in a room full of mirrors\nAll ...
# 333265  Waterfall, nothing can harm me at all,\nMy wor...
# 333538  Oh, help me in my weakness\nI heard the drifte...
# 337314  Hello, my friend\nSo happy to see you again\nI...
# 345256  Well, I wait around the train station\nWaitin'...
# 350681  It was twenty years ago today\nSgt. Pepper tau...
# 362735  Drifting\nOn a sea of forgotten teardrops\nOn ...
# 394577  Shoot down some of those airplanes your flyin'...
# 398606  The stars up above that play with laughing sam...
# 402312  Angel came down from heaven yesterday\nShe sta...
# 422851  They don't know\nThey don't know\nLike I know\...
# 430072  Should auld acquaintance be forgot,\nAnd never...
#
#                                                      tags  \
# 3248    [['blues', '100'], ['classic rock', '55'], ['r...
# 3280    [['classic rock', '100'], ['rock', '74'], ['ps...
# 12290   [['classic rock', '100'], ['rock', '69'], ['bl...
# 14588   [['blues', '100'], ['classic rock', '40'], ['g...
# 23330   [['classic rock', '100'], ['rock', '65'], ['ps...
# 24917   [['classic rock', '100'], ['rock', '68'], ['Ps...
# 25219   [['classic rock', '100'], ['rock', '63'], ['Ps...
# 26791   [['classic rock', '100'], ['rock', '75'], ['ji...
# 31404   [['rock', '100'], ['classic rock', '92'], ['ji...
# 35215   [['classic rock', '100'], ['rock', '83'], ['ps...
# 40056   [['classic rock', '100'], ['rock', '90'], ['bl...
# 42942   [['classic rock', '100'], ['rock', '74'], ['gu...
# 43288   [['classic rock', '100'], ['rock', '82'], ['60...
# 44301   [['blues', '100'], ['classic rock', '72'], ['b...
# 51597   [['classic rock', '100'], ['Psychedelic Rock',...
# 57478   [['classic rock', '100'], ['rock', '64'], ['60...
# 58069   [['classic rock', '100'], ['rock', '67'], ['ps...
# 67485   [['classic rock', '100'], ['rock', '69'], ['60...
# 68428   [['classic rock', '100'], ['rock', '83'], ['Ps...
# 73985   [['classic rock', '100'], ['rock', '84'], ['ps...
# 74940   [['classic rock', '100'], ['rock', '61'], ['Ps...
# 79966   [['classic rock', '100'], ['rock', '59'], ['ps...
# 88826   [['classic rock', '100'], ['rock', '83'], ['bl...
# 89209   [['classic rock', '100'], ['Psychedelic Rock',...
# 99135   [['classic rock', '100'], ['blues', '58'], ['r...
# 109355  [['classic rock', '100'], ['blues', '85'], ['r...
# 110256  [['rock', '100'], ['classic rock', '100'], ['P...
# 125002  [['classic rock', '100'], ['rock', '84'], ['bl...
# 128683  [['classic rock', '100'], ['rock', '82'], ['Ps...
# 140665  [['classic rock', '100'], ['rock', '57'], ['gu...
# 143597  [["60's", '100'], ['classic rock', '83'], ['Ps...
# 178810  [['classic rock', '100'], ['blues', '89'], ['r...
# 181286  [['classic rock', '100'], ['rock', '73'], ['bl...
# 188009  [['classic rock', '100'], ['rock', '83'], ['ps...
# 198127  [['classic rock', '100'], ['rock', '82'], ['gu...
# 206547  [['classic rock', '100'], ['rock', '78'], ['ps...
# 210450  [['classic rock', '100'], ['rock', '75'], ['Ps...
# 211532  [['classic rock', '100'], ['60s', '60'], ['roc...
# 221171  [['classic rock', '100'], ['Hendrix', '20'], [...
# 252408  [['classic rock', '100'], ['rock', '61'], ['ji...
# 260595  [['classic rock', '100'], ['rock', '74'], ['ps...
# 263751  [['classic rock', '100'], ['rock', '68'], ['ji...
# 270020  [['classic rock', '100'], ['blues', '50'], ['r...
# 281715  [['rock', '100'], ['classic rock', '90'], ['ps...
# 305408  [['blues', '100'], ['classic rock', '63'], ['j...
# 313013  [['classic rock', '100'], ['rock', '42'], ['de...
# 322175  [['classic rock', '100'], ['rock', '53'], ['Ps...
# 325882  [['rock', '100'], ['classic rock', '100'], ['P...
# 333265  [['classic rock', '100'], ['rock', '71'], ['ps...
# 333538  [['classic rock', '100'], ['blues', '100'], ['...
# 337314  [['classic rock', '100'], ['rock', '52'], ['ji...
# 345256  [['blues', '100'], ['classic rock', '77'], ['b...
# 350681  [['cover', '100'], ['classic rock', '50'], ['b...
# 362735  [['classic rock', '100'], ['Psychedelic Rock',...
# 394577  [['classic rock', '100'], ['rock', '69'], ['ps...
# 398606  [['rock', '100'], ['classic rock', '100'], ['b...
# 402312  [['classic rock', '100'], ['Psychedelic Rock',...
# 422851  [['rock', '100'], ['classic rock', '97'], ['bl...
# 430072  [['rock', '100'], ['classic rock', '100'], ['p...
#
#                          timestamp                  id
# 3248    2011-08-01 23:22:50.940844  TRAETTV12903CBBD09
# 305408  2011-08-12 09:57:02.212968  TRRSXLN12903CC15B8
# 313013  2011-08-15 13:12:36.835359  TRSEPPX12903D021D6
# 322175  2011-08-01 14:34:46.589986  TRSSOQW12903CBBCEA
# 325882  2011-08-15 10:42:05.394605  TRSYEXF128F42261AB
# 333265  2011-09-08 04:42:12.354786  TRTJMIU128F4265BF8
# 333538  2011-08-04 18:41:00.332088  TRTJXFS128E078F4FF
# 337314  2011-08-03 06:48:50.615853  TRTPUOC12903CC15BE
# 345256  2011-08-10 04:17:45.262832  TRUCGHE12903CBBD0F
# 350681  2011-08-09 17:16:16.537684  TRUKPHI12903CC1814
# 362735  2011-08-15 10:22:14.907563  TRVCXSD12903CC15A5
# 394577  2011-08-02 03:13:49.814956  TRWZPYD12903CBB89F
# 398606  2011-08-04 13:35:42.227924  TRXFVBV12903CCE42D
# 402312  2011-09-08 04:55:13.271071  TRXLLVZ12903CC16D4
# 422851  2011-08-10 22:35:17.801168  TRYQUXL12903CBB89C
# 430072  2011-08-11 10:13:42.288189  TRZBYEX12903CBBCF0

# %%
n=12290
print(df['artist'].loc[n] +' , ', df['song'].loc[n])
# Out:
# Jimi Hendrix ,  Hear My Train A Comin'

# %%
print(df['lyrics'].loc[n])
# Out:
# Well, I wait around the train station
# Waitin' for that train
# Waitin' for the train, yeah
# Take me home, yeah
# From this lonesome place
# Well, now a while lotta people put me down a lotta changes
# My girl had called me a disgrace
#
# Dig
# The tears burnin'
# Tears burnin' me
# Tears burnin' me
# Way down in my heart
# Well, you know it's too bad, little girl,
# It's too bad
# Too bad we have to part (have to part)
#
# Dig
# Gonna leave this town, yeah
# Gonna leave this town
# Gonna make a whole lotta money
# Gonna be big, yeah
# Gonna be big, yeah
# I'm gonna buy this town
# I'm gonna buy this town
# An' put it all in my shoe
# Might even give a piece to you
# That's what I'm gonna do,
# What I'm gonna do,
# What I'm gonna do

# %%
## Convert text to sequence input
#features = df['lyrics'].apply(lambda x: sent2seq(x, vocab, tok, seq_len))
#features = np.array(list(features))

def sent2seq(text, key, tok, l):
    words = tok(text)

    unknown = len(key.keys()) + 1

    seq = []
    for word in words:
        if word in key:
            seq.append(key[word] + 1)
        else:
            seq.append(unknown)

    if len(seq) > l:
        return seq[:l]
    else:
        padding = [0 for i in range(l - len(seq))]

        return (padding + seq)

    return seq

idx = sent2seq(df['lyrics'].loc[n], vocab, tok, seq_len)
print(idx)
[inv[x-1] for x in idx]
# Out:
# [1264, 790, 252, 4851, 790, 4851, 790, 2903, 36, 2903, 4478, 84, 4667, 4, 4667, 561, 933, 45, 3897, 2868]
# ['wait',
#  'train',
#  'station',
#  'waitin',
#  'train',
#  'waitin',
#  'train',
#  'yeah',
#  'home',
#  'yeah',
#  'lonesome',
#  'place',
#  'lotta',
#  'people',
#  'lotta',
#  'changes',
#  'girl',
#  'called',
#  'disgrace',
#  'dig']

# %%
len(vocab.keys())
# Out:
# 4977

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

i = 0

#sns.kdeplot(x, y, cmap=cmap, shade=True, cut=5, ax=ax)
ax = sns.heatmap(z[i].data.numpy())
ax.set_yticks = [inv[x-1] for x in idx]
